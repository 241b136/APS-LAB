# %% [markdown]
# <a href="https://colab.research.google.com/github/241b136/APS-LAB/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}
    visited = []

    distances[start] = 0

    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous[neighbor] = min_node

    return distances, previous


def shortest_path(previous, start, target):
    path = []
    node = target
    while node is not None:
        path.insert(0, node)
        node = previous[node]
    if path[0] == start:
        return path
    else:
        return None

graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'C': 5, 'D': 10},
    'C': {'E': 3},
    'D': {'F': 11},
    'E': {'D': 4},
    'F': {}
}
graph['G'] = {'F': 1, 'E': 2}
graph['H'] = {'A': 7, 'C': 6}
for start_node in ['A', 'C', 'H']:
    distances, previous = dijkstra(graph, start_node)
    print(f"\nSource: {start_node}")
    for target in graph:
        path = shortest_path(previous, start_node, target)
        if path:
            print(f"Shortest path to {target}: {path}, Distance = {distances[target]}")
        else:
            print(f"No path to {target}")
# Out:
# Source: A
# Shortest path to A: ['A'], Distance = 0
# Shortest path to B: ['A', 'B'], Distance = 4
# Shortest path to C: ['A', 'C'], Distance = 2
# Shortest path to D: ['A', 'C', 'E', 'D'], Distance = 9
# Shortest path to E: ['A', 'C', 'E'], Distance = 5
# Shortest path to F: ['A', 'C', 'E', 'D', 'F'], Distance = 20
# No path to G
# No path to H
#
# Source: C
# No path to A
# No path to B
# Shortest path to C: ['C'], Distance = 0
# Shortest path to D: ['C', 'E', 'D'], Distance = 7
# Shortest path to E: ['C', 'E'], Distance = 3
# Shortest path to F: ['C', 'E', 'D', 'F'], Distance = 18
# No path to G
# No path to H
#
# Source: H
# Shortest path to A: ['H', 'A'], Distance = 7
# Shortest path to B: ['H', 'A', 'B'], Distance = 11
# Shortest path to C: ['H', 'C'], Distance = 6
# Shortest path to D: ['H', 'C', 'E', 'D'], Distance = 13
# Shortest path to E: ['H', 'C', 'E'], Distance = 9
# Shortest path to F: ['H', 'C', 'E', 'D', 'F'], Distance = 24
# No path to G
# Shortest path to H: ['H'], Distance = 0

# %%
graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'C': 5, 'D': 10},
    'C': {'E': 3},
    'D': {'F': 11},
    'E': {'D': 4},
    'F': {}
}
graph['G'] = {'F': 1, 'E': 2}
graph['H'] = {'A': 7, 'C': 6}
for start_node in ['A', 'C', 'H']:
    distances, previous = dijkstra(graph, start_node)
    print(f"\nSource: {start_node}")
    for target in graph:
        path = shortest_path(previous, start_node, target)
        if path:
            print(f"Shortest path to {target}: {path}, Distance = {distances[target]}")
        else:
            print(f"No path to {target}")
# Out:
# Source: A
# Shortest path to A: ['A'], Distance = 0
# Shortest path to B: ['A', 'B'], Distance = 4
# Shortest path to C: ['A', 'C'], Distance = 2
# Shortest path to D: ['A', 'C', 'E', 'D'], Distance = 9
# Shortest path to E: ['A', 'C', 'E'], Distance = 5
# Shortest path to F: ['A', 'C', 'E', 'D', 'F'], Distance = 20
# No path to G
# No path to H
#
# Source: C
# No path to A
# No path to B
# Shortest path to C: ['C'], Distance = 0
# Shortest path to D: ['C', 'E', 'D'], Distance = 7
# Shortest path to E: ['C', 'E'], Distance = 3
# Shortest path to F: ['C', 'E', 'D', 'F'], Distance = 18
# No path to G
# No path to H
#
# Source: H
# Shortest path to A: ['H', 'A'], Distance = 7
# Shortest path to B: ['H', 'A', 'B'], Distance = 11
# Shortest path to C: ['H', 'C'], Distance = 6
# Shortest path to D: ['H', 'C', 'E', 'D'], Distance = 13
# Shortest path to E: ['H', 'C', 'E'], Distance = 9
# Shortest path to F: ['H', 'C', 'E', 'D', 'F'], Distance = 24
# No path to G
# Shortest path to H: ['H'], Distance = 0

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
